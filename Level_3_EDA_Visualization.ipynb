# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ml_df = pd.read_csv("Dataset/ML_Train_Level_Data.csv")

# %%
 ml_df.head()
# Out:
#    Train_No  Journey_Duration_Minutes  Total_Distance  Number_of_Stops
# 0       107                     105.0              78                4
# 1       108                     115.0              83                4
# 2       128                    1325.0             978               22
# 3       290                    9120.0            2694               14
# 4       401                    2190.0            1618               12

# %%
ml_df.shape
# Out:
# (11113, 4)

# %%
plt.scatter(
    ml_df["Total_Distance"],
    ml_df["Journey_Duration_Minutes"]
)

plt.xlabel("Total Distance")
plt.ylabel("Journey Duration (Minutes)")
plt.title("Distance vs Journey Duration")
plt.show()

# %%
plt.scatter(
    ml_df["Number_of_Stops"],
    ml_df["Journey_Duration_Minutes"]
)

plt.xlabel("Number of Stops")
plt.ylabel("Journey Duration (Minutes)")
plt.title("Number of Stops vs Journey Duration")
plt.show()

# %%
correlation = ml_df[
    ["Total_Distance", "Number_of_Stops", "Journey_Duration_Minutes"]
].corr()

correlation
# Out:
#                           Total_Distance  Number_of_Stops  \
# Total_Distance                  1.000000         0.461854
# Number_of_Stops                 0.461854         1.000000
# Journey_Duration_Minutes        0.981364         0.544013
#
#                           Journey_Duration_Minutes
# Total_Distance                            0.981364
# Number_of_Stops                           0.544013
# Journey_Duration_Minutes                  1.000000

# %%
plt.imshow(correlation)

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=45
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.colorbar()
plt.title("Correlation Matrix")
plt.show()

# %%
pivot_table = pd.pivot_table(
    ml_df,
    index="Train_No",
    values="Number_of_Stops"
)

pivot_table.head(10)
# Out:
#           Number_of_Stops
# Train_No
# 107                   4.0
# 108                   4.0
# 128                  22.0
# 290                  14.0
# 401                  12.0
# 421                   5.0
# 422                   5.0
# 477                  14.0
# 502                   9.0
# 504                   3.0
